# %%
source(paste(
    getwd(),
    'gbif_functions.R',
    sep = '/'
  ))

# %%
#Inputs for Running Sample Query
vSpeciesNames = c("Rhinoceros unicornis","Bubo bengalensis")
top_left_lat_deg = 8.5
top_left_lon_deg = 72
bottom_right_lat_deg = 31.5
bottom_right_lon_deg = 91
year= '2022'

# %%
dtSpecies<-
      fGetSpecies(
        vSpeciesNames = vSpeciesNames,
        top_left_lat_deg = top_left_lat_deg,
        top_left_lon_deg = top_left_lon_deg,
        bottom_right_lat_deg = bottom_right_lat_deg,
        bottom_right_lon_deg = bottom_right_lon_deg,
        cNumberofDataPoints = 100000
      )

head(dtSpecies, 3)
# Out:
#   key        scientificName                      decimalLatitude
# 1 3698076810 Rhinoceros unicornis Linnaeus, 1758 28.54071
# 2 3705786638 Rhinoceros unicornis Linnaeus, 1758 27.48311
# 3 3743151392 Rhinoceros unicornis Linnaeus, 1758 28.58336
#   decimalLongitude issues  datasetKey
# 1 81.31420         cdround 50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2 84.45048         cdround 50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3 81.36684         cdround 50c9509d-22c7-4a22-a47d-8c48425ef4a7
#   publishingOrgKey                     installationKey
# 1 28eb1a3f-1c15-4a95-931a-4af90ecb574d 997448a8-f762-11e1-a439-00145eb45e9a
# 2 28eb1a3f-1c15-4a95-931a-4af90ecb574d 997448a8-f762-11e1-a439-00145eb45e9a
# 3 28eb1a3f-1c15-4a95-931a-4af90ecb574d 997448a8-f762-11e1-a439-00145eb45e9a
#   publishingCountry protocol    ⋯ establishmentMeans infraspecificEpithet
# 1 US                DWC_ARCHIVE ⋯ NA                 NA
# 2 US                DWC_ARCHIVE ⋯ NA                 NA
# 3 US                DWC_ARCHIVE ⋯ NA                 NA
#   endDayOfYear bibliographicCitation georeferencedDate georeferenceRemarks
# 1 NA           NA                    NA                NA
# 2 NA           NA                    NA                NA
# 3 NA           NA                    NA                NA
#   associatedReferences taxonRemarks previousIdentifications municipality
# 1 NA                   NA           NA                      NA
# 2 NA                   NA           NA                      NA
# 3 NA                   NA           NA                      NA

# %%
  dtStations<-
    fGetClimateStations(
      country_name = ,
      centre_lat_deg = median(dtSpecies$decimalLatitude),
      centre_lon_deg = median(dtSpecies$decimalLongitude),
      no_of_stations = 50,
      use_country = F
      )
head(dtStations,3)
# Out:
# [1] "http://ogimet.com/cgi-bin/gsynres?lang=en&state=United+Kingdom&osum=no&fmt=html&ord=REV&ano=2022&mes=07&day=04&hora=06&ndays=1&Send=send"
# /tmp/RtmpZYIWHY/file177311b5b2449
#   wmo_id station_names      lon      lat      alt distance [km]
# 1 03796  Langdon Bay        1.350007 51.13334 117 9675.024
# 2 03797  Manston            1.350007 51.35001  55 9681.734
# 3 03931  Tibenham Airfield  1.150003 52.45001  52 9738.151
# plot without title

# %%
  dtClimate<- 
    fGetHourlyWeatherData(
      vListofStationIDs = dtStations$wmo_id ,
      vListofStationNames = dtStations$station_names,
      vListofStationLat_Deg = dtStations$lat,
      vListofStationLon_Deg = dtStations$lon,
      year = year
      )

head(dtClimate,3)
# Out:
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037960-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773158900852
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037970-99999-2022.gz"
# HTTP error 404.
#   Check station name or year. The created link is not working properly:
#   https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037970-99999-2022.gz[1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/039310-99999-2022.gz"
# HTTP error 404.
#   Check station name or year. The created link is not working properly:
#   https://www1.ncdc.noaa.gov/pub/data/noaa/2022/039310-99999-2022.gz[1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/036930-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177311ea36d30
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/035900-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177312305121
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/034880-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177312ff5e01b
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/038820-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177312d2ee7ce
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/036840-99999-2022.gz"
# /tmp/RtmpZYIWHY/file17731404f918e
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/034820-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177318ab9334
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037810-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773118f7806
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/038760-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773160e34cd4
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037690-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773165534377
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037700-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177315c7102c
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/033920-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177311c210cc5
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/034690-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177313f2636a1
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/036720-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773148cc6696
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/033850-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773121e93cbc
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/036800-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177314ce4a14c
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037720-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177313d502db7
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/033910-99999-2022.gz"
# /tmp/RtmpZYIWHY/file17731dcfa222
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/035600-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177315337a069
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037680-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177314a6b5719
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/038720-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773168339af3
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/034620-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773145568511
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/036600-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177316979bd13
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037610-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773178d71845
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/032920-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177316568d175
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/033790-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773151bbe893
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/033770-99999-2022.gz"
# /tmp/RtmpZYIWHY/file17731120cd5da
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/038660-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177315fcaf3e4
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/033730-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177311bb57c33
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/036580-99999-2022.gz"
# /tmp/RtmpZYIWHY/file17731197a1e76
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/033820-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177314c8ba341
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037490-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177312f384278
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/032810-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177312bd09753
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/035440-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177315f2c710e
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/038950-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773143518531
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/038620-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773120b00517
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/036490-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177316820397b
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037460-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773136e60709
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/033540-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177316b5db65
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037430-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773157a9add1
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/032750-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177316e062128
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/036470-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177314f34d8b9
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/035350-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177313c7c1bfa
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/037400-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177311b30a0e9
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/038940-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177311cc09e9d
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/032650-99999-2022.gz"
# /tmp/RtmpZYIWHY/file17731b051fbe
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/038570-99999-2022.gz"
# /tmp/RtmpZYIWHY/file1773114d32de7
# [1] "https://www1.ncdc.noaa.gov/pub/data/noaa/2022/035290-99999-2022.gz"
# /tmp/RtmpZYIWHY/file177311a0a9df1
#   date                year month day hour lon   lat    alt t2m  dpt2m ws  wd
# 1 2022-01-01 00:00:00 2022 1     1   0    1.343 51.134 117 11.2 11.1  6.8 240
# 2 2022-01-01 01:00:00 2022 1     1   1    1.343 51.134 117 10.7 10.6  4.4 220
# 3 2022-01-01 02:00:00 2022 1     1   2    1.343 51.134 117 10.7 10.6  4.7 220
#   slp    visibility station_name station_id station_lat_deg station_lon_deg
# 1 1022.5 NA         Langdon Bay  03796      51.13334        1.350007
# 2 1022.0 NA         Langdon Bay  03796      51.13334        1.350007
# 3 1021.8 NA         Langdon Bay  03796      51.13334        1.350007

# %%
dtRawSpecies<- dtSpecies
dtRawClimate<-dtClimate

# %%
# Cleaning/subsetting the datasets, standardizing some names
dtSpecies<- 
  dtRawSpecies[,
         list(
           species,
           speciesKey,
           
           lat_deg = decimalLatitude,
           lon_deg = decimalLongitude,
           gps_error_m = coordinateUncertaintyInMeters,
           stateProvince,
           country,
           
           year,
           month,
           day,
           eventDate,
           
           publishingCountry,
           basisOfRecord,
           recordedBy
         )
  ]

# %%
# Questions to Answer: ?
# What is our strategy to merge by geo coordiantes
# 1 deg is roughly = 100kms, so 2nd decimal place is around 1km. Is that good enough for climate data?
# Data that we have has upto 4 decimal places. Shall we go more granular?

dtClimate<- 
  dtRawClimate[,
     list(
       mean_air_temp_C = mean(t2m,na.rm = T)
     ),
     list(
       station_name,
       lat_deg = round(lat,2),
       lon_deg = round(lon,2),
       year,
       month,
       day
     )
  ]

# %%
dtResult<-
  rbindlist(
    lapply(
      1:nrow(dtSpecies),
      function(iRow){
        # iRow = 14
        #print(iRow)
        dtUniqueStations<- dtClimate[, .N, list( station_name, lat_deg, lon_deg)]
        dtTemp<-dtSpecies[iRow]
        
        
        iLat_deg = dtTemp[,lat_deg]
        iLon_deg = dtTemp[,lon_deg]
        
        dtUniqueStations[,
                         distance_m := 
                           dtHaversine(
                             lat_from = iLat_deg,
                             lon_from = iLon_deg,
                             lat_to = lat_deg,
                             lon_to = lon_deg
                           )                 
        ]
        
        setorder(dtUniqueStations, distance_m)
        
        iTemp<- dtClimate[
          station_name == 
            dtUniqueStations[1,station_name] & 
            year == dtTemp[, year] &
            month == dtTemp[, month] & 
            day == dtTemp[, day],
          mean_air_temp_C
        ][1]
        
        dtTemp[,mean_air_temp_C := iTemp]
        
        return(dtTemp)
        
        
        
        
      }
    ),
    use.names = T,
    fill = T
  )

# %%
head(dtResult,10)
# Out:
#    species              speciesKey lat_deg  lon_deg  gps_error_m stateProvince
# 1  Rhinoceros unicornis 5220113    28.54071 81.31420 29607       Mid-Western
# 2  Rhinoceros unicornis 5220113    27.48311 84.45048 29727       Central
# 3  Rhinoceros unicornis 5220113    28.58336 81.36684 29607       Mid-Western
# 4  Rhinoceros unicornis 5220113    28.56486 81.32029 29607       Mid-Western
# 5  Rhinoceros unicornis 5220113    27.44307 84.54298 29727       Central
# 6  Rhinoceros unicornis 5220113    27.55505 84.13999 29727       Central
# 7  Rhinoceros unicornis 5220113    27.60574 84.16430 29704       West
# 8  Rhinoceros unicornis 5220113    27.68047 84.15472 29704       West
# 9  Rhinoceros unicornis 5220113    26.62741 90.81376 29822       Assam
# 10 Rhinoceros unicornis 5220113    26.70601 89.37070 29822       West Bengal
#    country year month day eventDate           publishingCountry
# 1  Nepal   2022  2    17  2022-02-17T12:35:26 US
# 2  Nepal   2022  2    23  2022-02-23T15:29:23 US
# 3  Nepal   2022  2    17  2022-02-17T13:34:00 US
# 4  Nepal   2022  2    18  2022-02-18T13:43:00 US
# 5  Nepal   2022  2    26  2022-02-26T18:24:00 US
# 6  Nepal   2022  2    28  2022-02-28T14:27:00 US
# 7  Nepal   2022  3    10  2022-03-10T13:12:00 US
# 8  Nepal   2021  4     6  2021-04-06T12:51:56 US
# 9  India   2021 12    16  2021-12-16T16:33:57 US
# 10 India   2021 12    22  2021-12-22T09:37:19 US
#    basisOfRecord     recordedBy   mean_air_temp_C
# 1  HUMAN_OBSERVATION packardr90   NA
# 2  HUMAN_OBSERVATION missmagwong  NA
# 3  HUMAN_OBSERVATION packardr90   NA
# 4  HUMAN_OBSERVATION packardr90   NA
# 5  HUMAN_OBSERVATION packardr90   NA
# 6  HUMAN_OBSERVATION packardr90   NA
# 7  HUMAN_OBSERVATION miromrh      NA
# 8  HUMAN_OBSERVATION prakashman   NA
# 9  HUMAN_OBSERVATION P Jeganathan NA
# 10 HUMAN_OBSERVATION kaustavr     NA
